# %%
from confluent_kafka import Producer, KafkaError
from confluent_kafka.admin import AdminClient, NewTopic, NewPartitions
import json

admin_client = AdminClient({'bootstrap.servers': 'kafka:9092'})

# %%
# LIST TOPICS

md = admin_client.list_topics(timeout=10)
print(" {} topics:".format(len(md.topics)))
for t in iter(md.topics.values()):
    if t.error is not None:
        errstr = ": {}".format(t.error)
    else:
        errstr = ""
    print("  \"{}\" with {} partition(s){}".format(t, len(t.partitions), errstr))
# Out:
#  5 topics:
#   "_schemas" with 1 partition(s)
#   "DEALER1_TRUCKS" with 1 partition(s)
#   "DEALER2_USERS" with 1 partition(s)
#   "DEALER1_CARS" with 1 partition(s)
#   "DEALER2_VEHICLES" with 1 partition(s)

# %%
from confluent_kafka import Consumer, KafkaError
import json

c = Consumer(
    {
        'bootstrap.servers': 'kafka:9092',
        'group.id': 'test',
        'auto.offset.reset': 'earliest'
    }
)

c.subscribe(["DEALER1_CARS","DEALER1_TRUCKS"])

waiting = False

try:
    while True:
        msg = c.poll(1.0)                                        # retrieve records
        if msg is None:
            if waiting:
                print(".",end =" ")
            else:
                print("Waiting",end =" ")
                waiting = True
            continue
        elif msg.error():
            print('error: {}'.format(msg.error()))
            waiting = False
        else:
            value = json.loads(msg.value())                      # get the value of the message (json.loads)
            topic = msg.topic()                               # get the key of the message
            print("\nConsumed record from {} with value {}"
                  .format(topic, value))
            waiting = False
except KeyboardInterrupt:
    pass
finally:
    c.close()
# Out:
# Waiting
# Consumed record from DEALER1_TRUCKS with value {'user': 'Laura Baker', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'HHST532', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Wayne Flower', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'DM89JKD', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Ann Duppstadt', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'KMCIOWM', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Geneva Crews', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': '674GHDF', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Richard Tillman', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'JSDJFI3', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Henry Romero', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'H39DXCO', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Richard Tillman', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'JSDJFI3', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Wayne Flower', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'DM89JKD', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Laura Baker', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'HHST532', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Hubert Grissett', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'HHST532', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Hubert Grissett', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'DM89JKD', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Ann Duppstadt', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'KMCIOWM', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Richard Tillman', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'KMCIOWM', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Henry Romero', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'JSDJFI3', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Henry Romero', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'H39DXCO', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Richard Tillman', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'KMCIOWM', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Geneva Crews', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'H39DXCO', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Geneva Crews', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': 'H39DXCO', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Geneva Crews', 'manifacturer': 'Iveco', 'model': 'Daily', 'plate': '674GHDF', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_TRUCKS with value {'user': 'Henry Romero', 'manifacturer': 'Fiat', 'model': 'Ducato', 'plate': 'JSDJFI3', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Molly Davis', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Laura Baker', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'William Diaz', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Molly Davis', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'William Diaz', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Hubert Grissett', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'DR7TGF0', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Robert Shake', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Laura Baker', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Lucille Bouchard', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model Y', 'plate': 'AB7TGX0', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Laura Baker', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Frank Cover', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Wanda Carver', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Frank Cover', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Hubert Grissett', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Mayme Jones', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'RT5Y6ZX', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'ADFTR34', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Mayme Jones', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Robert Shake', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'William Diaz', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Wanda Carver', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Laura Baker', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Michael Ferrell', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Stephine Trent', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Geneva Crews', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Mayme Jones', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'RT5Y6ZX', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Mayme Jones', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'H3NP56Y', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'ADFTR34', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model Y', 'plate': 'AB7TGX0', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Lucille Bouchard', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'William Diaz', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Kevin Rodriguez', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Catherine Crandell', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Michael Ferrell', 'manifacturer': 'Fiat', 'model': 'Panda', 'plate': 'FJ7PUJJ', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Stephine Trent', 'manifacturer': 'Tesla', 'model': 'Model S', 'plate': 'JFGJ60A', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Catherine Crandell', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Hubert Grissett', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'START', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Geneva Crews', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'FGL1X62', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Douglas Fitch', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': 'DR7TGF0', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Kevin Rodriguez', 'manifacturer': 'Fiat', 'model': 'Tipo', 'plate': 'G16MEAR', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
#
# Consumed record from DEALER1_CARS with value {'user': 'Hubert Grissett', 'manifacturer': 'Tesla', 'model': 'Model X', 'plate': '8NMSMII', 'status': 'END', 'ts': '2022-01-12 20:31:07'}
# Waiting .

# %%
from confluent_kafka import Consumer, KafkaError
import json

c = Consumer(
    {
        'bootstrap.servers': 'kafka:9092',
        'group.id': 'test',
        'auto.offset.reset': 'earliest'
    }
)

c.subscribe(["DEALER2_VEHICLES","DEALER2_USERS"])

waiting = False

try:
    while True:
        msg = c.poll(1.0)                                        # retrieve records
        if msg is None:
            if waiting:
                print(".",end =" ")
            else:
                print("Waiting",end =" ")
                waiting = True
            continue
        elif msg.error():
            print('error: {}'.format(msg.error()))
            waiting = False
        else:
            value = json.loads(msg.value())                      # get the value of the message (json.loads)
            topic = msg.topic()                               # get the key of the message
            print("\nConsumed record from {} with value {}"
                  .format(topic, value))
            waiting = False
except KeyboardInterrupt:
    pass
finally:
    c.close()
# Out:
# Consumed record from DEALER2_USERS with value {'userID': '3', 'name': 'Kevin Rodriguez'}
#
# Consumed record from DEALER2_USERS with value {'userID': '4', 'name': 'Catherine Crandell'}
#
# Consumed record from DEALER2_USERS with value {'userID': '1', 'name': 'Douglas Fitch'}
#
# Consumed record from DEALER2_USERS with value {'userID': '2', 'name': 'William Diaz'}
#
# Consumed record from DEALER2_USERS with value {'userID': '9', 'name': 'Mark Haws'}
#
# Consumed record from DEALER2_USERS with value {'userID': '6', 'name': 'Wayne Flower'}
#
# Consumed record from DEALER2_USERS with value {'userID': '7', 'name': 'Laura Baker'}
#
# Consumed record from DEALER2_USERS with value {'userID': '8', 'name': 'Jane McPeak'}
#
# Consumed record from DEALER2_USERS with value {'userID': '5', 'name': 'Richard Tillman'}
#
# Consumed record from DEALER2_USERS with value {'userID': '10', 'name': 'Jeanie Morgan'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car,', 'manifacturer': 'Audi', 'model': 'A3', 'plate': 'DFU4HJF', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '4', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'FJK48FJ', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '1', 'type': 'car', 'manifacturer': 'Porsche', 'model': '911', 'plate': 'UF94JF', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '2', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'AL3SLS', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '1', 'type': 'car', 'manifacturer': 'Porsche', 'model': '911', 'plate': 'UF94JF', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Audi', 'model': 'TT', 'plate': '045MDAX', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '4', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'FJK48FJ', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': 'KD94KDS', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '6', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': '012JKD0', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Audi', 'model': 'TT', 'plate': '045MDAX', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '7', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Citan', 'plate': 'B38SDJA', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '8', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '5', 'type': 'car', 'manifacturer': 'Audi', 'model': 'TT', 'plate': '045MDAX', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car,', 'manifacturer': 'Audi', 'model': 'A3', 'plate': 'DFU4HJF', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car,', 'manifacturer': 'Audi', 'model': 'A3', 'plate': 'DFU4HJF', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '6', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': '012JKD0', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '10', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': '012JKD0', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '2', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'AL3SLS', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Porsche', 'model': '911', 'plate': 'UF94JF', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '10', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': '012JKD0', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '7', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Citan', 'plate': 'B38SDJA', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Citan', 'plate': 'B38SDJA', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'AL3SLS', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car,', 'manifacturer': 'Audi', 'model': 'A3', 'plate': 'DFU4HJF', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': 'KD94KDS', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '8', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '1', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Citan', 'plate': 'B38SDJA', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '9', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'AL3SLS', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Porsche', 'model': '911', 'plate': 'UF94JF', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'FJK48FJ', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '1', 'type': 'car', 'manifacturer': 'Porsche', 'model': 'Cayenne', 'plate': 'A49CKED', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '4', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': 'KD94KDS', 'status': 'START', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '3', 'type': 'car', 'manifacturer': 'Audi', 'model': 'A4', 'plate': 'FJK48FJ', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '4', 'type': 'truck', 'manifacturer': 'Mercedes', 'model': 'Vito', 'plate': 'KD94KDS', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
#
# Consumed record from DEALER2_VEHICLES with value {'userID': '5', 'type': 'car', 'manifacturer': 'Audi', 'model': 'TT', 'plate': '045MDAX', 'status': 'END', 'ts': '2022-01-12 20:31:16'}
# Waiting . . . . . .
